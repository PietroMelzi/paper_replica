# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %%
import pathlib
font_csvs =  [str(p) for p in pathlib.Path('preproc_data/afpdb').glob("*.csv")]
data = pd.read_csv(font_csvs[0], header=None)
fig, axs = plt.subplots(5, 1)
for i in range(5):
    axs[i].plot(data.iloc[:,i+2][:300])

# %%
from tensorflow.keras import datasets, layers, models
import numpy as np

model = models.Sequential()
lay = layers.BatchNormalization(trainable=True)

# %%
train = np.array([[[0.5],[1.],[1.]],[[0.2],[0.3],[0.1]]])
labels = np.array([1, 1])
print(train.shape)
for i in range(500):
    lay(train, training=True)
lay.weights
# Out:
# (2, 3, 1)
# [<tf.Variable 'batch_normalization_5/gamma:0' shape=(1,) dtype=float32, numpy=array([1.], dtype=float32)>,
#  <tf.Variable 'batch_normalization_5/beta:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>,
#  <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(1,) dtype=float32, numpy=array([0.5166637], dtype=float32)>,
#  <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(1,) dtype=float32, numpy=array([0.13138962], dtype=float32)>]
